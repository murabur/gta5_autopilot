# %% [markdown]
# # Linear Algebra (NumPy)
#
# Bu bölümde NumPy içinde lineer cebirin en temel işlemleri anlatılır.
#
# Bu konular özellikle:
# - matematiksel düşünme
# - matris işlemleri
# - machine learning temeli
# - computer vision dönüşümleri
#
# için önemlidir.
#
# Not:
# `transpose` daha önce işlendiği için burada tekrar ana konu gibi değil, gerektiği yerde kısa referans olarak ele alınabilir.
#
# ---
#
# ## Linear algebra nedir
#
# Linear algebra, vektörler ve matrislerle yapılan matematiksel işlemler alanıdır.
#
# NumPy tarafında bu bölümün temel amacı şudur:
#
# - vektör nedir
# - matris nedir
# - iki vektör nasıl çarpılır
# - iki matris nasıl çarpılır
# - bir matrisin tersi nedir
# - determinant nedir

# %%
#vektör
import numpy as np

v = np.array([1, 2, 3])

print("v:", v)
print("v.shape:", v.shape)
