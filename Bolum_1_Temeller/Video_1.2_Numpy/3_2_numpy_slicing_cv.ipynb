# %% [markdown]
# # Computer vision açısından numpy indexing ve slicing kullanımı
# - Görüntüler numpy arrayleri ile ifade edilir
# - Opencv görüntüleri numpy array olarak okur
# - Bu görüntüler (H, W, C) Heigth, Width, Channels şeklinde shape'e sahiptir
# - örnek img.shape (720,1280,3)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()

# 2. Bir üst klasöre çık (Örn: C:\projeler)
parent_dir = os.path.dirname(current_dir)
parent_dir = os.path.dirname(parent_dir)

# 3. Üst klasördeki assets'e giden yolu birleştir
img_path = os.path.join(parent_dir, "assets", "ornek_goruntu.png")

print(f"Erişilen Yol: {img_path}")

img = cv2.imread(img_path)
if img is not None:
    print("Görüntü başarıyla yakalandı!")

plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()


parent_dir = os.path.dirname(current_dir)
parent_dir = os.path.dirname(parent_dir)

# 3. Üst klasördeki assets'e giden yolu birleştir
img_path = os.path.join(parent_dir, "assets", "ornek_goruntu.png")

print(f"Erişilen Yol: {img_path}")
pixel = img[50,50]
print("pixel BGR değeri::", pixel)
#img[y,x]

img = cv2.imread(img_path)
if img is not None:
    print("Görüntü başarıyla yakalandı")

plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#Bir görüntünün sadece bir kanalını almak
blue = img[:, :, 0]
green = img[:, :, 1]
red = img[:, :, 2]

#ilk :  tüm satırlar
#ikinci : tüm sütunlar
#üçüncü sayı : kanal

# %% [markdown]
# # ROI

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()

# 2. Bir üst klasöre çık (Örn: C:\projeler)
parent_dir = os.path.dirname(current_dir)
parent_dir = os.path.dirname(parent_dir)

# 3. Üst klasördeki assets'e giden yolu birleştir
img_path = os.path.join(parent_dir, "assets", "ornek_goruntu.png")

print(f"Erişilen Yol: {img_path}")



img = cv2.imread(img_path)
if img is not None:
    print("Görüntü başarıyla yakalandı")

plt.figure()
plt.imshow(cv2.cvtColor(img[200:400,300:600], cv2.COLOR_BGR2RGB)) #köşeli parantez içinde numpy slicing ile slicing yapılıyor. 
#önce y1:y2 ardından x1:x2
plt.show()

# %%
left_half = img[:, :img.shape[1]//2]     #sol yarı
right_half = img[:, img.shape[1]//2:]    #sağ yarı
top_half = img[:img.shape[0]//2, :]      #üst yarı
bottom_half = img[img.shape[0]//2:, :]   #alt yarı

# %% [markdown]
#  # Belirli pixelleri değiştirme

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()

# 2. Bir üst klasöre çık (Örn: C:\projeler)
parent_dir = os.path.dirname(current_dir)
parent_dir = os.path.dirname(parent_dir)

# 3. Üst klasördeki assets'e giden yolu birleştir
img_path = os.path.join(parent_dir, "assets", "ornek_goruntu.png")

print(f"Erişilen Yol: {img_path}")


img = cv2.imread(img_path)
if img is not None:
    print("Görüntü başarıyla yakalandı")

img[200:300, 300:500] = [0, 255, 0]

plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #köşeli parantez içinde numpy slicing ile slicing yapılıyor. 
#önce y1:y2 ardından x1:x2
plt.show()

# %% [markdown]
# # Maskeleme ile Slicing farkı

# %%
#Slicingde dikdörtden bölge alınır
#Boolean maskingde koşula göre piksel seçilir.



import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

current_dir = os.getcwd()

# 2. Bir üst klasöre çık (Örn: C:\projeler)
parent_dir = os.path.dirname(current_dir)
parent_dir = os.path.dirname(parent_dir)

# 3. Üst klasördeki assets'e giden yolu birleştir
img_path = os.path.join(parent_dir, "assets", "ornek_goruntu.png")

print(f"Erişilen Yol: {img_path}")


img = cv2.imread(img_path)
if img is not None:
    print("Görüntü başarıyla yakalandı")

mask = img[:, :, 2] > 200
img[mask] = [0, 0, 255]


plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #köşeli parantez içinde numpy slicing ile slicing yapılıyor. 
#önce y1:y2 ardından x1:x2
plt.show()

# %% [markdown]
# # Computer Vision'da indexing ve slicing ile yapılan tipik işler

# %%
gray_like_blue = img[:, :, 0] #kanal ayırma
car_region = img[y1:y2, x1:x2] #ROI çıkarma
road_zone = img[400:, :] #alt bölgeyi işleme
pixel = img[y, x] #tek piksel okuma
img[100:200, 200:300] = [255, 255, 255] #bölgeyi boyama
img[:, :, 2] = 0 #sadece bir kanalı değiştirme

#Bu projede
row = road_mask[y, :] #satır satır yol merkezi bulma
img[y1:y2, x1:x2] #ROI

#kanal bazlı işlem
img[:, :, 0]
img[:, :, 1]
img[:, :, 2]
