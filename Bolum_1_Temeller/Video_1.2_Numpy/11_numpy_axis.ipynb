# %% [markdown]
# Axis, Numpy'de hangi eksen boyunca işlem yapılacağını belirler.

# %%
import numpy as np

A = np.array([
    [1,2,3],
    [4,5,6]
])

A.shape
# Out:
# (2, 3)

# %% [markdown]
# Axis 0 - Satır
#
# Axis 1 - Sütun

# %%
import numpy as np

A = np.array([
    [1,2,3],
    [4,5,6]
])


print(f"Axis = 0 {np.sum(A, axis = 0)}")
print(f"Axis = 1 {np.sum(A, axis = 1)}")
# Out:
# Axis = 0 [5 7 9]
# Axis = 1 [ 6 15]
